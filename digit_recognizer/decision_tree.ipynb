# %%
from sklearn.svm import SVC
from data_preparation import get_train_test_data
from submission import create_submission
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
# X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = get_train_test_data()

gnb = GaussianNB()

# %%
y_pred = gnb.fit(X_train, y_train).predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81       816
#            1       0.75      0.96      0.84       909
#            2       0.90      0.25      0.39       846
#            3       0.72      0.41      0.52       937
#            4       0.85      0.17      0.29       839
#            5       0.65      0.09      0.16       702
#            6       0.59      0.95      0.73       785
#            7       0.91      0.34      0.49       893
#            8       0.32      0.62      0.43       835
#            9       0.39      0.94      0.55       838
#
#     accuracy                           0.57      8400
#    macro avg       0.68      0.56      0.52      8400
# weighted avg       0.69      0.57      0.53      8400

# %%
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 8400 points : 529

# %%
clf = RandomForestClassifier(n_estimators=1000, max_depth=100, max_features="log2", criterion="gini", random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, max_features='log2', n_estimators=1000,
#                        random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9632142857142857

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       816
#            1       0.98      0.99      0.99       909
#            2       0.97      0.96      0.96       846
#            3       0.95      0.94      0.94       937
#            4       0.96      0.96      0.96       839
#            5       0.97      0.95      0.96       702
#            6       0.96      0.98      0.97       785
#            7       0.97      0.95      0.96       893
#            8       0.94      0.94      0.94       835
#            9       0.93      0.95      0.94       838
#
#     accuracy                           0.96      8400
#    macro avg       0.96      0.96      0.96      8400
# weighted avg       0.96      0.96      0.96      8400
